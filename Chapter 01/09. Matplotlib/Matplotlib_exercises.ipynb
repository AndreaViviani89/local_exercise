# %% [markdown]
# # Matplotlib

# %% [markdown]
# For these exercises, we are using Pandas and Matplotlib to visualize Company Sales Data.
#
# We will be using the following dataset: https://pynative.com/wp-content/uploads/2019/01/company_sales_data.csv

# %% [markdown]
# ### Exercise 1: Read the Total profit of all months and show it using a line plot.
# Total profit data provided for each month. The enerated line plot must include the following properties:<br>
# - X label name = Month Number
# - Y label name = Total profit
#
# The line plot graph should look like this:
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Write your code here
url = 'https://pynative.com/wp-content/uploads/2019/01/company_sales_data.csv'

data = pd.read_csv(url)
# Out:
# Text(0, 0.5, 'Total profit')

# %%
url = 'https://pynative.com/wp-content/uploads/2019/01/company_sales_data.csv'

data = pd.read_csv('C:/Users/andre/Desktop/File jupyter/company_sales_data.csv')

data.head()


profitList = data ['total_profit'].tolist()
monthList  = data ['month_number'].tolist()
plt.plot(monthList, profitList, label = 'Month-wise Profit data of last year')
plt.xlabel('Month number')
plt.ylabel('Total profit')
plt.xticks(monthList)
plt.title('Company profit per month')
plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.show()

# %% [markdown]
# ### Exercise 2: Get the Total profit of all months and show a line plot with the following Style properties:
# - Line Style dotted and Line color should be red
# - Show legend at the lower right location.
# - X label name = Month Number
# - Y label name = Sold units number
# - Add a circle marker.
# - Line marker color as read
# - Line width should be 3
#
# The line plot graph should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here

# %%
data = pd.read_csv('C:/Users/andre/Desktop/File jupyter/company_sales_data.csv')

total_profit = data ['total_profit'].tolist()
month_number = data ['month_number'].tolist()

plt.plot(month_number, total_profit, label= "Profit data",
        color = "r", marker = "o", markerfacecolor = "k",
        linestyle = "--", linewidth=3)

plt.xlabel('Month number')
plt.ylabel('Profit')
plt.legend(loc = "lower right")
plt.xticks(month_number)
plt.title('Company sales data of last year')
plt.yticks([200000, 250000, 300000, 350000, 400000])

plt.show()

# %% [markdown]
# ### Exercise 3: Read all product sales data and show it using a multiline plot.
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product).
#
# The graph should look like this:
# ![image.png](attachment:image.png)

# %%
data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
# Write your code here
fig, ax = plt.subplots(figsize=(10,8))

plt.plot(data["month_number"], data["facecream"],label="Facecream", marker="o", linewidth=3)
plt.plot(data["month_number"], data["facewash"], label="Facewash", marker="o", linewidth=3)
plt.plot(data["month_number"], data["toothpaste"], label="Toothpaste", marker="o", linewidth=3)
plt.plot(data["month_number"], data["bathingsoap"], label="Bathingsoap", marker="o", linewidth=3)
plt.plot(data["month_number"], data["shampoo"], label="Shampoo", marker="o", linewidth=3)
plt.plot(data["month_number"], data["moisturizer"], label="Moisturizer", marker="o", linewidth=3)

plt.xlabel("Month numbers")
plt.ylabel("Sales units in number")
plt.legend(loc= "upper left")
plt.title("Sales data")
plt.show()

# %% [markdown]
# ### Exercise 4: Read the toothpaste sales data of each month and show it using a scatter plot.
# Also, add a grid in the plot (the grid line style should be “–“).
#
# The scatter plot should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
ig, ax = plt.subplots(figsize=(10,8))

plt.scatter(data["month_number"], data["toothpaste"], label="Toothpaste Sales data")

plt.xlabel("Month numbers")
plt.ylabel("Numbere of unit sold")
plt.legend(loc= "upper left")
plt.title("Toothpaste Sales data")
plt.grid(True, linewidth = 1, linestyle = "--")
plt.xticks(month_number)
plt.show()

# %% [markdown]
# ### Exercise 5: Read the face cream and facewash product sales data and show it using the bar chart.
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.
#
# The bar chart should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here

fig, ax = plt.subplots(figsize=(10,8))


ax.bar(data["month_number"]-0.35/2, data["facecream"], 0.35, label="Facecream")
ax.bar(data["month_number"]+0.35/2, data["facewash"], 0.35, label="Facewash")
ax.set_xlabel("Month numbers")
ax.set_ylabel("Sales units in number")
ax.set_title("Facewash and Facecream Sales Data")
ax.set_xticks(month_number)

ax.grid(True, linestyle = ("--"), linewidth=1)

ax.legend()
plt.show()

# %% [markdown]
# ### Exercise 6: Read the sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk.
# The bar chart should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here


ig, ax = plt.subplots(figsize=(10,8))

plt.bar(data["month_number"], data["bathingsoap"], label="Bathingsoap")

plt.xlabel("Month numbers")
plt.ylabel("Sales units in number")
plt.title("Bathing soap Sales data")
plt.grid(True, linewidth = 1, linestyle = "--")
plt.xticks(month_number)
plt.savefig("C:/Users/andre/Documents/Strive_repository/local_exercise/Chapter 01/09. Matplotlib/sales_data_of_bathingsoap.png", dpi=200)
plt.show()

# %% [markdown]
# ### Exercise 7: Read the total profit of each month and show it using the histogram to see the most common profit ranges.
# The histogram should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
ig, ax = plt.subplots(figsize=(10,8))

plt.hist(data['total_profit'], bins=10)
plt.xlabel('profit range in dollars')
plt.ylabel('Actual profit in dollar')
plt.title('Profit data')
# Out:
# Text(0.5, 1.0, 'Profit data')

# %% [markdown]
# ### Exercise 8: Calculate the total sale data for last year for each product and show it using a Pie chart.
# Note: In the Pie chart you should display the Number of units sold per year for each product in percentage.
#
# The Pie chart should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here


labels = ['FaceCream', 'FaseWash', 'ToothPaste', 'Bathing soap', 'Shampoo', 'Moisturizer']
salesData   = [data ['facecream'].sum(), data ['facewash'].sum(), data ['toothpaste'].sum(), 
         data ['bathingsoap'].sum(), data ['shampoo'].sum(), data ['moisturizer'].sum()]
plt.axis("equal")
plt.pie(salesData, labels=labels, autopct='%1.1f%%')
plt.legend(loc='lower right')
plt.title('Sales data')
plt.show()

# %% [markdown]
# ### Exercise 9: Read the Bathing soap facewash of all months and display it using the Subplot.
# The Subplot should look like this:

# %%
# Write your code here

ig, ax = plt.subplots(figsize=(10,8))


plt.subplot(2, 1, 1)
plt.plot(data['month_number'], data['bathingsoap'], color='black', label='bathsoap', marker='o', linewidth=3)
plt.subplot(2, 1, 2)
plt.plot(data['month_number'], data['facewash'], color='red', label='facewash', marker='o', linewidth=3)
plt.xlabel('Sales units in number')
plt.ylabel('Month number')
plt.xticks(month_number)
plt.title('Sales data of bathsoap')
# Out:
# Text(0.5, 1.0, 'Sales data of bathsoap')

# %% [markdown]
# ### Exercise 10: Read all product sales data and show it using the stack plot.
# The Stack plot should look like this:
# ![image.png](attachment:image.png)

# %%
data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
# Write your code here


# plt.plot(data['month_number'], data['facecream'], color='m', label='face cream', linewidth=3)
# plt.plot(data['month_number'], data['facewash'], color='c', label='Face wash', linewidth=3)
# plt.plot(data['month_number'], data['toothpaste'], color='r', label='tooth paste', linewidth=3)
# plt.plot(data['month_number'], data['bathingsoap'], color='k', label='bath soap', linewidth=3)
# plt.plot(data['month_number'], data['shampoo'], color='g', label='Shampoo', linewidth=3)
# plt.plot(data['month_number'], data['moisturizer'], color='y', label='Moisturizer', linewidth=3)


ig, ax = plt.subplots(figsize=(10,8))

plt.stackplot(data['month_number'], data['facecream'], data['facewash'], data['toothpaste'], data['bathingsoap'], data['shampoo'], data['moisturizer'], colors=['m','c','r','k','g','y'])

plt.xlabel('Month Number')
plt.ylabel('Sales unints in Number')
plt.title('Total sales')
plt.legend(loc='upper left')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
