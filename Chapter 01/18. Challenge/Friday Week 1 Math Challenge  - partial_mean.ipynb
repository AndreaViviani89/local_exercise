# %% [markdown]
# ## Rotation matrix

# %% [markdown]
# Multiplying a vector by a matrix is equivalent to apply a linear transformation to that vector. One common example, is the rotation matrix: ![image](https://wikimedia.org/api/rest_v1/media/math/render/svg/678b1828be1c7064bc3f25cd1cb323f88f0d8acf)

# %% [markdown]
# where the theta is the angle by which the vector is rotated.
#
# Could you create a function that:
#
# - receive the angle as input argument and a vector as input
# - plots both the original and the transformed vector on the same plot but with different colors
#
# ?
#
# BONUS: https://matplotlib.org/stable/api/animation_api.html
#
# Can you make an animation that shows the intermediate steps of the rotation and save into a gif?
#
# Tip: don't contraint your imagination.

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/chriswmann/datasets/master/500_Person_Gender_Height_Weight_Index.csv")

# %%
df
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %% [markdown]
# You have collected some data about 500 samples of people.
#
# You have information about the weight, the height, the gender and the BMI of the person.
#
# For the BMI:
#
# - 0 means 'Extremely Weak'
# - 1 means 'Weak'
# - 2 means 'Normal'
# - 3 means 'Overweight'
# - 4 means 'Obesity'
# - 5 means 'Extreme Obesity'

# %% [markdown]
# Before starting: *what does each row represent?*

# %%
df.Index.value_counts()
# Out:
# 5    198
# 4    130
# 2     69
# 3     68
# 1     22
# 0     13
# Name: Index, dtype: int64

# %%
female_extremely_weak = df[df.Gender == 'Female'][df.Index == 0]
female_weak = df[df.Gender == 'Female'][df.Index == 1]
female_normal = df[df.Gender == 'Female'][df.Index == 2]
female_overweight = df[df.Gender == 'Female'][df.Index == 3]
female_obesity = df[df.Gender == 'Female'][df.Index == 4]
female_extremely_obesity = df[df.Gender == 'Female'][df.Index == 5]

male_extremely_weak = df[df.Gender == 'Male'][df.Index == 0]
male_weak = df[df.Gender == 'Male'][df.Index == 1]
male_normal = df[df.Gender == 'Male'][df.Index == 2]
male_overweight = df[df.Gender == 'Male'][df.Index == 3]
male_obesity = df[df.Gender == 'Male'][df.Index == 4]
male_extremely_obesity = df[df.Gender == 'Male'][df.Index == 5]
# Out:
# C:\Users\andre\AppData\Local\Temp/ipykernel_17732/3421428241.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   female_extremely_weak = df[df.Gender == 'Female'][df.Index == 0]
# C:\Users\andre\AppData\Local\Temp/ipykernel_17732/3421428241.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   female_weak = df[df.Gender == 'Female'][df.Index == 1]
# C:\Users\andre\AppData\Local\Temp/ipykernel_17732/3421428241.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   female_normal = df[df.Gender == 'Female'][df.Index == 2]
# C:\Users\andre\AppData\Local\Temp/ipykernel_17732/3421428241.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   female_overweight = df[df.Gender == 'Female'][df.Index == 3]
# C:\Users\andre\AppData\Local\Temp/ipykernel_17732/3421428241.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   female_obesity = df[df.Gender == 'Female'][df.Index == 4]
# C:\Users\andre\AppData\Local\Temp/ipykernel_17732/3421428241.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   female_extremely_obesity = df[df.Gender == 'Female'][df.Index == 5]
# C:\Users\andre\AppData\Local\Temp/ipykernel_17732/3421428241.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   male_extremely_weak = df[df.Gender == 'Male'][df.Index == 0]
# C:\Users\andre\AppData\Local\Temp/ipykernel_17732/3421428241.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   male_weak = df[df.Gender == 'Male'][df.Index == 1]
# C:\Users\andre\AppData\Local\Temp/ipykernel_17732/3421428241.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   male_normal = df[df.Gender == 'Male'][df.Index == 2]
# C:\Users\andre\AppData\Local\Temp/ipykernel_17732/3421428241.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   male_overweight = df[df.Gender == 'Male'][df.Index == 3]
# C:\Users\andre\AppData\Local\Temp/ipykernel_17732/3421428241.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   male_obesity = df[df.Gender == 'Male'][df.Index == 4]
# C:\Users\andre\AppData\Local\Temp/ipykernel_17732/3421428241.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   male_extremely_obesity = df[df.Gender == 'Male'][df.Index == 5]

# %% [markdown]
# - Can you make an overview about them? For example: how many women are overweight? How many men? Etc etc.
#
# - Can you plot the data such that on the x axis you have the weight, on the y axis you have the height, and the individuals of the same BMI (column index) get colored with the same color?

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
status = ['Extremely Weak', 'Weak', 'Normal', 'Overweight', 'Obesity', 'Extremely Obesity']
male_status = [len(male_extremely_weak), len(male_weak), len(male_normal), len(male_overweight), len(male_obesity), len(male_extremely_obesity)]
female_status = [len(female_extremely_weak), len(female_weak), len(female_normal), len(female_overweight), len(female_obesity), len(female_extremely_obesity)]

print(status)
print(male_status)
print(female_status)
# Out:
# ['Extremely Weak', 'Weak', 'Normal', 'Overweight', 'Obesity', 'Extremely Obesity']
# [6, 15, 28, 32, 59, 105]
# [7, 7, 41, 36, 71, 93]

# %%
df.groupby('Gender')['Index'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Gender,Index'>

# %%
plt.scatter(df['Weight'], df['Height'], c=df.Index )

# %%
import seaborn as sns

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='Weight', y='Height', hue='Index', data=df ,palette="deep")
plt.scatter(df.Weight.mean(),df.Height.mean(),color='r', marker='o')
plt.show()

# %% [markdown]
# Do the same but only for males:

# %%
male_height = df[df.Gender == 'Male'].Height
male_weight = df[df.Gender == 'Male'].Weight

# %%
plt.scatter(male_weight, male_height, c=male_weight.index)
plt.scatter(df.Weight.mean(),df.Height.mean(),color='r', marker='o')

# %% [markdown]
# Repeat for females:

# %%
female_height = df[df.Gender == 'Female'].Height
female_weight = df[df.Gender == 'Female'].Weight

# %%
plt.scatter(female_weight, female_height, c=female_weight.index)
plt.scatter(df.Weight.mean(),df.Height.mean(),color='r', marker='o')

# %% [markdown]
# Can you plot the histograms of the height of males, females and the total dataset?
#
# Do the same for the weight.

# %%
# Males height --> Example
# Out:
# <AxesSubplot:>

# %%
# Males height

plt.hist(male_height)
plt.grid(True, linestyle='--', linewidth = 1)
plt.title('Males height', color='White')
# Out:
# Text(0.5, 1.0, 'Males height')

# %%
# Males weight --> Example
# Out:
# <AxesSubplot:>

# %%
# Males weight

plt.hist(male_weight)
plt.grid(True, linestyle='--', linewidth = 1)
plt.title('Males weight', color='White')
# Out:
# Text(0.5, 1.0, 'Males weight')

# %%
# Females height --> Example
# Out:
# <AxesSubplot:>

# %%
# Females Height

plt.hist(female_height)
plt.grid(True, linestyle='--', linewidth = 1)
plt.title('Female height', color='White')
# Out:
# Text(0.5, 1.0, 'Female height')

# %%
# Females Weight

plt.hist(female_weight)
plt.grid(True, linestyle='--', linewidth = 1)
plt.title('Females height', color='White')
# Out:
# Text(0.5, 1.0, 'Females height')

# %% [markdown]
# ## Euclidean Distance

# %% [markdown]
# In the above data, the mean of all the points is given by the sum of all the points divided by the number of them. Pandas, does it for us by doing:

# %%
mean_vector = [df.Weight.mean(), df.Height.mean()]
mean_vector
# Out:
# [106.0, 169.944]

# %% [markdown]
# - I know that is less efficient, but I want to see if you understand the concept of the mean of vectors: can you redo the process with a for loop?

# %% [markdown]
# - Plot the data again together with the mean value that must be visible in the middle, maybe with another size or marker and color

# %%
'''I know that is less efficient, but I want to see if you understand the concept of the mean of vectors: can you redo the process with a for loop?'''


height = 0
for i in df.Height:
    height += i
mean_height = height/len(df.Height)
print(mean_height)

weight = 0
for j in df.Weight:
    weight += j
mean_weight = weight/len(df.Weight)
print(mean_weight)
# Out:
# 169.944
# 106.0

# %%
plt.scatter(df['Weight'], df['Height'], c=df.Index )
plt.scatter(mean_weight, mean_height, marker='o', s=200, c='red')

# %%
# Example

# %% [markdown]
# It's not surprising that is perfectly in the middle, is it?
#
# Now, compute the mean of the elements that have a specific BMI: for example, the mean of all the elements with index 1, then the mean of the elements of index 2...
#
# Plot the mean of the all points as above together with the means of the different groups, all with different colors. Don't plot the rest of the points, they would lead to confusion.
#
# Don't forget to add the legend!

# %%
df.groupby('Index').mean()
# Out:
#            Height      Weight
# Index
# 0      187.538462   51.692308
# 1      184.772727   59.409091
# 2      174.260870   69.086957
# 3      175.985294   86.882353
# 4      173.876923  107.953846
# 5      160.979798  132.888889

# %%
index_means_weight = df.groupby('Index').Weight.mean()
index_means_height = df.groupby('Index').Height.mean()

means_0 = [index_means_weight[0], index_means_height[0]]
means_1 = [index_means_weight[1], index_means_height[1]]
means_2 = [index_means_weight[2], index_means_height[2]]
means_3 = [index_means_weight[3], index_means_height[3]]
means_4 = [index_means_weight[4], index_means_height[4]]
means_5 = [index_means_weight[5], index_means_height[5]]

plt.figure(figsize=(12,8))
plt.scatter(x=index_means_weight[0], y=index_means_height[0], s=200, label='Extremely Weak')
plt.scatter(x=index_means_weight[1], y=index_means_height[1], s=200, label='Weak')
plt.scatter(x=index_means_weight[2], y=index_means_height[2], s=200, label='Normal')
plt.scatter(x=index_means_weight[3], y=index_means_height[3], s=200, label='Overweight')
plt.scatter(x=index_means_weight[4], y=index_means_height[4], s=200, label='Obesity')
plt.scatter(x=index_means_weight[5], y=index_means_height[5], s=200, label='Extremely Obesity')
plt.scatter(x=mean_weight, y=mean_height, color='k', marker='*', s= 200, label='Mean')
plt.legend()

plt.show()

# %% [markdown]
# The differences look more evident now, right?
#
# For each of the points on the plot, except for the "Mean" point, can you compute the euclidean distance from the mean vector? (Hey, I'm using point, vector, samples to refer to the same thing! This is because data points have multiple names, like Spanish people https://www.youtube.com/watch?v=z7qYTNp17ao ).
#
# Remember, if you have two points $v = (v1, v2)$ and $w = (w1, w2)$, the euclidean distance is given by the formula:
#
# $$||v-w|| = \sqrt{(v1-w1)^{2} + (v2-w2)^{2})}$$
#
# or it looks like the norm of a difference in numpy... or the `euclidean` method of scipy... Up to you, as long as you get the result to your awesome boss.

# %% [markdown]
# # PCA
#
# Install the `scikit-learn` library by running `conda install -c conda-forge scikit-learn` on your terminal or installing `scikit-learn` from your Anaconda Navigator.

# %%
from sklearn.datasets import load_digits
digits = load_digits()

# %% [markdown]
# This library contains a dataset with hand written digits. Let's see some samples:

# %%
fig = plt.figure(figsize=(6, 6))  # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for i in range(64):
    ax = fig.add_subplot(8, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(digits.images[i], cmap=plt.cm.binary, interpolation='nearest')
    # label the image with the target value
    ax.text(0, 7, str(digits.target[i]))

# %% [markdown]
# Don't worry about the code above, I just copy pasted it from the documentation.
#
# The images have a lot of dimensions (each pixel can be thought as a coordinate):

# %%
digits.images[0]
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
digits.images[0].shape
# Out:
# (8, 8)

# %% [markdown]
# precisely 8x8 dimensions (so 64 coordinates!). How can we plot a system of 64 coordinates? Well, it's pretty hard to do on a piece of a paper, even with a 3D representation. I can imagine some ways to represent 5D data, with a lot of creativity, but still...
#
# So there's this technique, called PCA, that "project" the data into two main axes, so that you can look at them from a distance, so that they look as 2D points:

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
proj = pca.fit_transform(digits.data)
plt.scatter(proj[:, 0], proj[:, 1], c=digits.target, cmap="Paired")
plt.colorbar()

# %% [markdown]
# here we go! It's still a little mess, isn't it? However, look at how the points related to 0 are close to the points related to 6! and the 1s to the 7s! Make sense, right? They look very similar when you draw them!
#
# I want you to redo the same thing you did for BMI: let's put the projections in a dataframe:

# %%
digits_df = pd.DataFrame({"x":proj[:, 0], "y":proj[:, 1], "label":digits.target})

# %%
digits_df
# Out:
#               x          y  label
# 0     -1.259469  21.274884      0
# 1      7.957610 -20.768702      1
# 2      6.991926  -9.955984      2
# 3    -15.906107   3.332465      3
# 4     23.306869   4.269057      4
# ...         ...        ...    ...
# 1792 -14.606629  13.344124      9
# 1793   6.464577  20.567298      0
# 1794  10.801284  -6.960252      8
# 1795  -4.872102  12.423952      9
# 1796  -0.344388   6.365551      8
#
# [1797 rows x 3 columns]

# %% [markdown]
# Don't worry if I use `digits.target` for example, it's just something provided by the sklearn library and I'm taking advantage of it. In real life, it's not that easy for each dataset! However, what looks like magic now, will be easier in the ML module!

# %% [markdown]
# - Question: what does the column "label" represent?

# %% [markdown]
# ### Exercise
#
# - Group the dataframe by the labels, and compute the means w.r.t. the means and plot only them.
# - Don't forget the legend!
# - Hint: set `plt.xlim([-40,40]` so that the legend doesn't overlap

# %% [markdown]
# ## Finally: surprise me! What can you bring more than the other team?
