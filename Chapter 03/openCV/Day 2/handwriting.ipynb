# %%
import torch
import cv2
import matplotlib.pyplot as plt

# %%
my_img = cv2.imread('tre.jpg')
plt.figure(figsize=(10, 6))
plt.imshow(my_img, cmap='gray')

# %%
retval, dst = cv2.threshold(my_img, 100, 255, cv2.THRESH_BINARY_INV)
plt.figure(figsize=(10, 6))
plt.imshow(dst, cmap='gray')
